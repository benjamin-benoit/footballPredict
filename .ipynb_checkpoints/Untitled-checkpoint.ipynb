# %% [markdown]
# # Football Predict
#
# <ul>
#     <li>
#         <h3>Presentation</h3>
#         <ul>
#             <li>Problématique</li>
#             <li>Contexte</li>
#         </ul>
#     </li>
#       <li>
#         <h3>Collecte et exploration des données</h3>
#         <ul>
#             <li>Compréhension de la donnée</li>
#             <li>Data visualisation</li>
#             <li>Traitement / Encodage</li>
#         </ul>
#     </li>
#       <li>
#         <h3>Modélisation</h3>
#         <ul>
#             <li>Choix de l'algorithme</li>
#             <li>Validation et interprétation</li>
#         </ul>
#     </li>
#     <li>
#         <h3>Conclusion</h3>
#     </li>
# </ul>

# %% [markdown]
# <h2>Presentation</h2>
#
# <h4>Problématique</h4>
# Peut-on prévoir les résultats de football grâce aux anciens résultats ?
#
# <h4>Contexte</h4>
# Le sujet concerne les résultats matchs internationaux de football de 1972 à 2019, les données proviennent du site Kaggle.
#
# Les matchs vont de la "FIFA World Cup" à la "FIFI Wild Cup" en passant par les matchs amicaux réguliers.
#
# Les matches internationaux et masculin. Les données n'incluent pas les Jeux Olympiques ni les matches avec des équipes nationale B, U23 ou une équipe sélectionnée par la Ligue.

# %% [markdown]
# <h2>Collecte et exploration des données</h2>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("./results.csv")
data.head()
# Out:
#          date home_team away_team  home_score  away_score tournament     city  \
# 0  1872-11-30  Scotland   England           0           0   Friendly  Glasgow
# 1  1873-03-08   England  Scotland           4           2   Friendly   London
# 2  1874-03-07  Scotland   England           2           1   Friendly  Glasgow
# 3  1875-03-06   England  Scotland           2           2   Friendly   London
# 4  1876-03-04  Scotland   England           3           0   Friendly  Glasgow
#
#     country  neutral
# 0  Scotland    False
# 1   England    False
# 2  Scotland    False
# 3   England    False
# 4  Scotland    False

# %% [markdown]
# <h4>Compréhension de la donnée</h4>
# Nous avons les matchs avec la date et le nombre de buts à domicile et à l'extérieur sasn inclure les penaltys.
# On a également comme information si c'est un match amical, le lieu et le pays de l'évènement et s'il est neutre.
#
# Nous avons 41,540 résultats. En se basant sur ces résultats, nous pouvons avoir une prévision sur le résultat d'un match.

# %%
data.groupby(['home_team', 'away_team']).size()
# Out:
# home_team      away_team
# Abkhazia       Artsakh                     1
#                Chagos Islands              1
#                Chameria                    2
#                Kárpátalja                  1
#                Northern Cyprus             2
#                Occitania                   2
#                Panjab                      1
#                South Ossetia               2
#                Sápmi                       1
#                Tamil Eelam                 1
#                Tibet                       1
#                United Koreans in Japan     1
#                Western Armenia             2
# Afghanistan    Bangladesh                  2
#                Bhutan                      3
#                Cambodia                    2
#                Chinese Taipei              1
#                India                       5
#                Japan                       1
#                Jordan                      1
# ...
